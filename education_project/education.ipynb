# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('E:\Data\opzd.csv')
df.head(10)
# Out:
#        Отметка времени Укажите свою учебную группу  \
# 0  24.01.2022 13:26:24                       Д-213
# 1  24.01.2022 13:27:40                       Д-213
# 2  24.01.2022 13:29:36                       Д-213
# 3  24.01.2022 13:32:46                       Д-211
# 4  24.01.2022 13:35:27                       Д-213
# 5  24.01.2022 14:02:46                       Д-213
# 6  24.01.2022 14:03:05                       Д-212
# 7  24.01.2022 14:03:13                       Д-214
# 8  24.01.2022 14:04:00                       Д-212
# 9  24.01.2022 14:04:15                       Д-212
#
#    Оцените общее впечатление от дисциплины по десятибальной шкале (где 10 - интересная и полезная дисциплина, 1 - абсолютно неинтересная и бесполезная дисциплина)  \
# 0                                                  8
# 1                                                 10
# 2                                                  3
# 3                                                  6
# 4                                                 10
# 5                                                  9
# 6                                                  8
# 7                                                 10
# 8                                                  9
# 9                                                  8
#
#    Оцените удовлетворенность от взаимодействия с преподавателем практических занятий по дисциплине по десятибальной шкале (где 10 - полностью доволен преподавателем, проблем во взаимодействии не возникало)  \
# 0                                                  7
# 1                                                 10
# 2                                                  6
# 3                                                 10
# 4                                                 10
# 5                                                  8
# 6                                                 10
# 7                                                 10
# 8                                                 10
# 9                                                 10
#
#   Опишите, насколько сложно было получить допуск к экзамену относительно других дисциплин, которые вы изучали?  \
# 0  Получить допуск было очень легко (легче, чем п...
# 1  Проблем с получением допуска к экзамену не воз...
# 2  Получить допуск было очень легко (легче, чем п...
# 3  Получить допуск было очень легко (легче, чем п...
# 4  Проблем с получением допуска к экзамену не воз...
# 5  Получить допуск к экзамену сложно (сложнее, че...
# 6  Проблем с получением допуска к экзамену не воз...
# 7  Получить допуск было очень легко (легче, чем п...
# 8  Проблем с получением допуска к экзамену не воз...
# 9  Проблем с получением допуска к экзамену не воз...
#
#   Оцените, насколько было трудно освоить и понять дисциплину, а также укажите, какую роль в этом процессе занимают методические материалы   \
# 0  Дисциплина осваивается легко, дополнительных м...
# 1  Дисциплина осваивается примерно также, как и л...
# 2  Дисциплина осваивается легко, дополнительных м...
# 3  Дисциплина осваивается примерно также, как и л...
# 4  Дисциплина осваивается легко, дополнительных м...
# 5  Дисциплина осваивается легко, дополнительных м...
# 6  Дисциплина осваивается примерно также, как и л...
# 7  Дисциплина осваивается легко без использования...
# 8  Дисциплина осваивается легко, дополнительных м...
# 9  Дисциплина осваивается примерно также, как и л...
#
#   Опишите, пожалуйста, общее впечатление от дисциплины: что понравилось/не понравилось, что бы вы предложили улучшить (заполняется по желанию)
# 0     Создать видео объяснения по построению задания
# 1  В общем и целом понравилось все, начиная с сам...
# 2                                           Балдежно
# 3                             Very good, cool 😎 👌 👍
# 4                                                NaN
# 5  Хотелось бы более подробного объяснения выполн...
# 6                                                NaN
# 7                                               Все
# 8                                                NaN
# 9                                                NaN

# %%
df = df.rename(columns ={ 'Отметка времени' : 'time', 'Укажите свою учебную группу' : 'group', 
              'Оцените общее впечатление от дисциплины по десятибальной шкале (где 10 - интересная и полезная дисциплина, 1 - абсолютно неинтересная и бесполезная дисциплина)' : 'discipline_rating',
              'Оцените удовлетворенность от взаимодействия с преподавателем практических занятий по дисциплине по десятибальной шкале (где 10 - полностью доволен преподавателем, проблем во взаимодействии не возникало)' : 'teacher_rating',
               'Опишите, насколько сложно было получить допуск к экзамену относительно других дисциплин, которые вы изучали?': 'pass',
               'Оцените, насколько было трудно освоить и понять дисциплину, а также укажите, какую роль в этом процессе занимают методические материалы ' : 'complexity',
               'Опишите, пожалуйста, общее впечатление от дисциплины: что понравилось/не понравилось, что бы вы предложили улучшить (заполняется по желанию)' : 'comment' }
              )

df = df.fillna('Комментарий отсутствует')

# %%
groups = sorted(df['group'].unique())
print(groups)
df.groupby('group')['group'].count()
# Out:
# ['Д-211', 'Д-212', 'Д-213', 'Д-214', 'Д-215']
# group
# Д-211    10
# Д-212    11
# Д-213    10
# Д-214    11
# Д-215    17
# Name: group, dtype: int64

# %%
median_discipline_rating = df.groupby('group')['discipline_rating'].median().tolist()
mean_discipline_rating = df.groupby('group')['discipline_rating'].mean().tolist()

median_discipline_rating = [round(v,1) for v in median_discipline_rating]
mean_discipline_rating = [round(v,1) for v in mean_discipline_rating]

# %%
fig = sns.barplot (x = groups, y = mean_discipline_rating, palette="Blues_d")
fig.figure.suptitle('Средний балл', fontsize = 18)

plt.xlabel("Группа", size=14)
plt.ylabel("Оценка", size=14)
plt.bar_label(fig.containers[0],size=16, label_type='center')
# Out:
# [Text(0, 0, '7.7'),
#  Text(0, 0, '8.9'),
#  Text(0, 0, '7.3'),
#  Text(0, 0, '7.4'),
#  Text(0, 0, '8.4')]

# %%
fig = sns.barplot (x = groups, y = median_discipline_rating, palette="Blues_d")
fig.figure.suptitle('Медианный балл', fontsize = 18)

plt.xlabel("Группа", size=14)
plt.ylabel("Оценка", size=14)
plt.bar_label(fig.containers[0],size=16, label_type='center')
# Out:
# [Text(0, 0, '7.5'),
#  Text(0, 0, '9'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8')]

# %%
median_teacher_rating = df.groupby('group')['teacher_rating'].median().tolist()
mean_teacher_rating = df.groupby('group')['teacher_rating'].mean().tolist()

median_teacher_rating = [round(v,1) for v in median_teacher_rating]
mean_teacher_rating = [round(v,1) for v in mean_teacher_rating]

# %%
fig = sns.barplot (x = groups, y = median_teacher_rating, palette="Blues_d")
fig.figure.suptitle('Медианный балл', fontsize = 18)

plt.xlabel("Группа", size=14)
plt.ylabel("Оценка", size=14)
plt.bar_label(fig.containers[0],size=16, label_type='center')
# Out:
# [Text(0, 0, '10'),
#  Text(0, 0, '10'),
#  Text(0, 0, '8'),
#  Text(0, 0, '10'),
#  Text(0, 0, '10')]

# %%
new_data = pd.DataFrame({'Медиана': median_teacher_rating,
                   'Среднее': mean_teacher_rating}, index=groups)

ax = new_data.plot.bar(rot=0, color={"Медиана": "#2BD4E1", "Среднее": "#2B89E1"})

ax.figure.suptitle('Оценка преподавателя', fontsize = 18)

plt.xlabel("Группа", size=14)
plt.ylabel("Оценка", size=14)
plt.bar_label(ax.containers[1],size=8, label_type='center')
plt.bar_label(ax.containers[0],size=8, label_type='center')
# Out:
# [Text(0, 0, '10'),
#  Text(0, 0, '10'),
#  Text(0, 0, '8'),
#  Text(0, 0, '10'),
#  Text(0, 0, '10')]

# %%
new_data = pd.DataFrame({'Медиана': median_discipline_rating,
                   'Среднее': mean_discipline_rating}, index=groups)

ax = new_data.plot.bar(rot=0, color={"Медиана": "#2BD4E1", "Среднее": "#2B89E1"})

ax.figure.suptitle('Оценка предмета', fontsize = 18)

plt.xlabel("Группа", size=14)
plt.ylabel("Оценка", size=14)
plt.bar_label(ax.containers[1],size=8, label_type='center')
plt.bar_label(ax.containers[0],size=8, label_type='center')
# Out:
# [Text(0, 0, '7.5'),
#  Text(0, 0, '9'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8')]

# %%
pass_stat_1 = df.groupby('pass')['group'].count()
pass_stat_1 = pd.DataFrame({'Допуск':pass_stat_1.index, 'Кол-во ответов':pass_stat_1.values})

#display(pass_stat_1)
#pass_stat_1.columns

pass_stat_2 = df.groupby('complexity')['group'].count()
pass_stat_2 = pd.DataFrame({'Сложность':pass_stat_2.index, 'Кол-во ответов':pass_stat_2.values})

# %%
# Настройка цветовой гаммы
colors = sns.color_palette('pastel')[0:5]

# Рендеринг круговой диаграммы
plt.pie(pass_stat_1['Кол-во ответов'], labels = pass_stat_1['Допуск'], colors = colors, autopct='%.0f%%')
plt.show()

# %%
# Настройка цветовой гаммы
colors = sns.color_palette('pastel')[0:5]

# Рендеринг круговой диаграммы
plt.pie(pass_stat_2['Кол-во ответов'], labels = pass_stat_2['Сложность'], colors = colors, autopct='%.0f%%')
#plt.legend()
plt.show()

# %% [markdown]
# Итого:
# - 11% считают, что получить допуск к экзамену оказалось сложнее, чем по другим дисциплинам. 89% опрошенных не выделяют дисциплину по сложности получения допуска
# - 8% считают дисциплину трудной для освоения, при этом 3% считают, что методических материалов недостаточно.92% опрошенных не выделяют дисциплину по сложности освоенияd

# %%
print('Средняя оценка дисциплины', round(df['discipline_rating'].mean(),1))
print ('Медианная оценка дисциплины', df['discipline_rating'].median())
# Out:
# Средняя оценка дисциплины 8.0
# Медианная оценка дисциплины 8.0

# %%
print('Средняя оценка преподавателя', round(df['teacher_rating'].mean(),1))
print ('Медианная оценка преподавателя', df['teacher_rating'].median(), '- преимущественно преподаватели получили оценку 10')
# Out:
# Средняя оценка преподавателя 8.9
# Медианная оценка преподавателя 10.0 - преимущественно преподаватели получили оценку 10

# %%
comments = pd.DataFrame(sorted(df['comment'].unique()), columns=['Отзыв'])
#comments = pd.DataFrame(comments)
comments=comments.style.set_properties(**{'text-align': 'center', 'text_wrap': True})  
#display (comments)

comments.set_table_styles([
    {'selector': 'th.col_heading', 'props': 'text-align: center;'},
    {'selector': 'th.col_heading.level0', 'props': 'font-size: 1.5em;'},
    {'selector': 'td', 'props': 'text-align: center; font-weight: bold;'},
], overwrite=False)
display (comments)
# Out:
# <style type="text/css">
# #T_b4ea6_ th.col_heading {
#   text-align: center;
# }
# #T_b4ea6_ th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_b4ea6_ td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_b4ea6_row0_col0, #T_b4ea6_row1_col0, #T_b4ea6_row2_col0, #T_b4ea6_row3_col0, #T_b4ea6_row4_col0, #T_b4ea6_row5_col0, #T_b4ea6_row6_col0, #T_b4ea6_row7_col0, #T_b4ea6_row8_col0, #T_b4ea6_row9_col0, #T_b4ea6_row10_col0, #T_b4ea6_row11_col0, #T_b4ea6_row12_col0, #T_b4ea6_row13_col0, #T_b4ea6_row14_col0, #T_b4ea6_row15_col0, #T_b4ea6_row16_col0, #T_b4ea6_row17_col0, #T_b4ea6_row18_col0, #T_b4ea6_row19_col0, #T_b4ea6_row20_col0, #T_b4ea6_row21_col0, #T_b4ea6_row22_col0 {
#   text-align: center;
#   text_wrap: True;
# }
# </style>
# <table id="T_b4ea6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Отзыв</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4ea6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4ea6_row0_col0" class="data row0 col0" >Very good, cool 😎 👌 👍 </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b4ea6_row1_col0" class="data row1 col0" >Балдежно</td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b4ea6_row2_col0" class="data row2 col0" >Было бы удобно, если бы экзаменационные билеты были по РГР</td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b4ea6_row3_col0" class="data row3 col0" >В общем и целом понравилось все, начиная с самой дисциплину и заканчивая преподавателем </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b4ea6_row4_col0" class="data row4 col0" >В целом все понравилось </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b4ea6_row5_col0" class="data row5 col0" >Все </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b4ea6_row6_col0" class="data row6 col0" >Все понравилось </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b4ea6_row7_col0" class="data row7 col0" >Все понравилось, были сложности, но без них никак </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b4ea6_row8_col0" class="data row8 col0" >Дисциплина в целом была интересной, и если вовремя выполнять каждый этап работы и не бояться общаться с преподавателем на счёт правильности выполнения ргр, то никаких затруднений не должно возникать. Хотелось бы, чтобы в дополнительных материалах лучше показывался процесс выполнения работы. </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b4ea6_row9_col0" class="data row9 col0" >Дисциплина оставила положительные впечатления,  предложений по улучшению нет</td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b4ea6_row10_col0" class="data row10 col0" >Довольно интересная ргр. Правда, материал слишком растянут. Семестр – слишком много для такого количества работы.</td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b4ea6_row11_col0" class="data row11 col0" >Комментарий отсутствует</td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b4ea6_row12_col0" class="data row12 col0" >Мне все понравилось, было достаточно легко понять данную дисциплину </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b4ea6_row13_col0" class="data row13 col0" >Мне все понравилось, материал выдавался небольшими порциями, все темы хорошо объясняли, если возникали вопросы преподаватель давал пояснения. </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b4ea6_row14_col0" class="data row14 col0" >Норм все </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b4ea6_row15_col0" class="data row15 col0" >Очень понравилось! Доступное объяснение темы и интересный предмет. Лояльный и чуткий преподаватель) Правда, такой формат лекций не очень удобен для подготовки к экзамену. В качестве усвоения, бесспорно, хорошо, но для подготовки можно в конце семестра выложить файлы с лекциями в формате пдф или ворд</td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b4ea6_row16_col0" class="data row16 col0" >Побольше взаимодействия с преподователем </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b4ea6_row17_col0" class="data row17 col0" >Понравилось работать с планшетом, для выполнения ргр</td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b4ea6_row18_col0" class="data row18 col0" >Преподаватель по практике недостаточно понятно объясняет материал </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b4ea6_row19_col0" class="data row19 col0" >Создать видео объяснения по построению задания</td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b4ea6_row20_col0" class="data row20 col0" >Узнали очень много тонкостей, о которых даже не задумывались </td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b4ea6_row21_col0" class="data row21 col0" >Хотелось бы более подробного объяснения выполнения ргр</td>
#     </tr>
#     <tr>
#       <th id="T_b4ea6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b4ea6_row22_col0" class="data row22 col0" >ничего</td>
#     </tr>
#   </tbody>
# </table>
